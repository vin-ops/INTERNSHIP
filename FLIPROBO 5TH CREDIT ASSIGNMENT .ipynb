# %% [markdown]
# IMPORTING PACKAGES

# %%
import pandas as pd 
pd.set_option('display.max_columns',50)
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('FR credit Data file.csv')
df.head()                                    # checking the top 5 rows of the dataset
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# 0    220.13    260.13                2.0                0.0              1539
# 1   3691.26   3691.26               20.0                0.0              5787
# 2    900.13    900.13                3.0                0.0              1539
# 3    159.42    159.42               41.0                0.0               947
# 4   1098.90   1098.90                4.0                0.0              2309
#
#    cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# ...

# %%
df.shape   # checking the number of rows and columns
# Out:
# (209593, 37)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 37 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            209593 non-null  int64
#  1   label                 209593 non-null  int64
#  2   msisdn                209593 non-null  object
#  3   aon                   209593 non-null  float64
#  4   daily_decr30          209593 non-null  float64
#  5   daily_decr90          209593 non-null  float64
#  6   rental30              209593 non-null  float64
#  7   rental90              209593 non-null  float64
#  8   last_rech_date_ma     209593 non-null  float64
#  9   last_rech_date_da     209593 non-null  float64
#  10  last_rech_amt_ma      209593 non-null  int64
#  11  cnt_ma_rech30         209593 non-null  int64
#  12  fr_ma_rech30          209593 non-null  float64
#  13  sumamnt_ma_rech30     209593 non-null  float64
# ...

# %%
# convert the pdate as object to datetime 

df['pdate']=pd.to_datetime(df['pdate'])

# %%
df.isna().sum()  # there are no null values in this dataset
# Out:
# Unnamed: 0              0
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# ...

# %%
# dropping the unnamed column as its not of any benefit 

df=df.drop('Unnamed: 0',axis=1)

# %%
df.head()
# Out:
#    label       msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408I70789  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462I70374  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943I70372  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773I70781  241.0     21.228000     21.228000    159.42    159.42
# 4      1  03813I82730  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                2.0                0.0              1539              2
# 1               20.0                0.0              5787              1
# 2                3.0                0.0              1539              1
# 3               41.0                0.0               947              0
# 4                4.0                0.0              2309              7
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# ...

# %%
df.shape
# Out:
# (209593, 36)

# %%
df.describe() # there is a huge diffrence between 75th and the max values that shows the presence of outliers
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755168  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000      209593.000000      209593.000000
# mean     2692.581910    3483.406534        3755.847800        3712.202921
# std      4308.586781    5770.461279       53905.892230       53374.833430
# min    -23737.140000  -24720.580000         -29.000000         -29.000000
# ...

# %%
df.corr()
# Out:
#                          label       aon  daily_decr30  daily_decr90  \
# label                 1.000000 -0.003785      0.168298      0.166150
# aon                  -0.003785  1.000000      0.001104      0.000374
# daily_decr30          0.168298  0.001104      1.000000      0.977704
# daily_decr90          0.166150  0.000374      0.977704      1.000000
# rental30              0.058085 -0.000960      0.442066      0.434685
# rental90              0.075521 -0.000790      0.458977      0.471730
# last_rech_date_ma     0.003728  0.001692      0.000487      0.000908
# last_rech_date_da     0.001711 -0.001693     -0.001636     -0.001886
# last_rech_amt_ma      0.131804  0.004256      0.275837      0.264131
# cnt_ma_rech30         0.237331 -0.003148      0.451385      0.426707
# fr_ma_rech30          0.001330 -0.001163     -0.000577     -0.000343
# sumamnt_ma_rech30     0.202828  0.000707      0.636536      0.603886
# medianamnt_ma_rech30  0.141490  0.004306      0.295356      0.282960
# ...

# %%
plt.figure(figsize=(25,15))
sns.heatmap(df.corr(),annot=True)

# daily_decr30 and daily_decr90 are highly corelated with each other 
#rental30 and rental 90 are highly corelated 
#amt loan 30 with cnt loan 30 are highly corelated they are basically providing the same information
#payback 30 and payback 90 highly corelated
# Out:
# <AxesSubplot:>

# %%
df.label.value_counts()
# Out:
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %%
sns.countplot(data=df,x='label',hue='label')  # most of the customers are ble to payback 
                                              # however the data is imbalanced which is not good for the model to learn
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
pd.crosstab(df['amnt_loans30'],df['label'],margins=True)

# we can observe that people who are taking less amount of loan ,are not paying back as compare to taking higher amount
# Out:
# label             0       1     All
# amnt_loans30
# 0                 0    3259    3259
# 6             19655   56965   76620
# 12             3793   40591   44384
# 18             1398   24981   26379
# 24              612   17791   18403
# 30              297   11702   11999
# 36              145    8414    8559
# 42               81    5499    5580
# 48               61    3933    3994
# 54               33    2627    2660
# 60               24    2019    2043
# 66               13    1389    1402
# 72               13    1088    1101
# 78               11     731     742
# 84                7     573     580
# 90                4     390     394
# 96                7     326     333
# 102               4     248     252
# 108               1     181     182
# 114               2     133     135
# 120               0     119     119
# 126               0      80      80
# 132               0      92      92
# 138               0      64      64
# ...

# %%
#plotting all the box plot to checkt he outliers 
 #there are outliers present

# %%
df.iloc[:,2:12].plot(kind='box',subplots=True,figsize=(10,10),layout=(2,5))
# Out:
# aon                     AxesSubplot(0.125,0.536818;0.133621x0.343182)
# daily_decr30         AxesSubplot(0.285345,0.536818;0.133621x0.343182)
# daily_decr90          AxesSubplot(0.44569,0.536818;0.133621x0.343182)
# rental30             AxesSubplot(0.606034,0.536818;0.133621x0.343182)
# rental90             AxesSubplot(0.766379,0.536818;0.133621x0.343182)
# last_rech_date_ma          AxesSubplot(0.125,0.125;0.133621x0.343182)
# last_rech_date_da       AxesSubplot(0.285345,0.125;0.133621x0.343182)
# last_rech_amt_ma         AxesSubplot(0.44569,0.125;0.133621x0.343182)
# cnt_ma_rech30           AxesSubplot(0.606034,0.125;0.133621x0.343182)
# fr_ma_rech30            AxesSubplot(0.766379,0.125;0.133621x0.343182)
# dtype: object

# %%
df.iloc[:,12:24].plot(kind='box',subplots=True,figsize=(10,10),layout=(2,6))
df.iloc[:,24:35].plot(kind='box',subplots=True,figsize=(10,10),layout=(2,6))
# Out:
# cnt_loans30              AxesSubplot(0.125,0.536818;0.110714x0.343182)
# amnt_loans30          AxesSubplot(0.257857,0.536818;0.110714x0.343182)
# maxamnt_loans30       AxesSubplot(0.390714,0.536818;0.110714x0.343182)
# medianamnt_loans30    AxesSubplot(0.523571,0.536818;0.110714x0.343182)
# cnt_loans90           AxesSubplot(0.656429,0.536818;0.110714x0.343182)
# amnt_loans90          AxesSubplot(0.789286,0.536818;0.110714x0.343182)
# maxamnt_loans90             AxesSubplot(0.125,0.125;0.110714x0.343182)
# medianamnt_loans90       AxesSubplot(0.257857,0.125;0.110714x0.343182)
# payback30                AxesSubplot(0.390714,0.125;0.110714x0.343182)
# payback90                AxesSubplot(0.523571,0.125;0.110714x0.343182)
# dtype: object

# %%
plt.hist(df['rental30'])
plt.show()

# %%
plt.hist(df['aon'])
plt.show()

# %%
df.iloc[:,2:35].plot(kind='kde',subplots=True,layout=(6,6),figsize=(15,15))

# checking how the data is distributed in all columns
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
# ...

# %%
df.head()
# Out:
#    label       msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408I70789  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462I70374  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943I70372  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773I70781  241.0     21.228000     21.228000    159.42    159.42
# 4      1  03813I82730  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                2.0                0.0              1539              2
# 1               20.0                0.0              5787              1
# 2                3.0                0.0              1539              1
# 3               41.0                0.0               947              0
# 4                4.0                0.0              2309              7
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# ...

# %%
df.shape
# Out:
# (209593, 36)

# %%
# dividing the data for training and testing

# %%
x=df.iloc[:,2:34]
y=df.iloc[:,0]

# %%
print(x.shape)
print(y.shape)
# Out:
# (209593, 32)
# (209593,)

# %%
y.value_counts()  # we can observe the data is imbalanced
# Out:
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %%
# Apply smote to balance the data in y ,target 

from imblearn.over_sampling import SMOTE

# %%
smt=SMOTE()
x_train,y_train=smt.fit_resample(x,y)

# %%
y_train.value_counts()
# Out:
# 0    183431
# 1    183431
# Name: label, dtype: int64

# %%
# selecting the best feature 


from sklearn.ensemble import ExtraTreesClassifier
model=ExtraTreesClassifier()
model.fit(x,y)
# Out:
# ExtraTreesClassifier()

# %%
print(model.feature_importances_)
# Out:
# [0.07547998 0.12215827 0.12035311 0.07544611 0.07330275 0.0497822
#  0.00384325 0.02635761 0.03387999 0.01611932 0.0310339  0.02567289
#  0.03801561 0.04007077 0.03396252 0.0310952  0.02693517 0.04510634
#  0.00283828 0.00196903 0.00330416 0.00098076 0.02252939 0.02010619
#  0.00217258 0.00403312 0.00725387 0.0193395  0.00814835 0.00387091
#  0.01800369 0.01683518]

# %%
# plotting a ghraph to see the importance of best 20 features 

best_features=pd.Series(model.feature_importances_,index=x.columns)
best_features.nlargest(20).plot(kind='barh')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (167674, 32)
# (167674,)
# (41919, 32)
# (41919,)

# %%
# applying standard scaler to make the data balance as it has values in diffrent units 


from sklearn.preprocessing import StandardScaler

sc=StandardScaler()
sc.fit(x_train,x_test)
x_train=sc.transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import cross_val_score

# %%
# Applying grid search for logistic regression 
# I applied grid search for logistic and its taking a very long time so i had to put it as a comment 

#lg=LogisticRegression()

# %%
#param_grid = [    
   # {'penalty' : ['l1', 'l2', 'elasticnet', 'none'],
   # 'C' : np.logspace(-4, 4, 20),
    #'solver' : ['lbfgs','newton-cg','liblinear','sag','saga'],
    #'max_iter' : [100, 1000,2500, 5000]
   # }
#]

# %%
from sklearn.model_selection import GridSearchCV
#glg = GridSearchCV(lg, param_grid = param_grid, cv = 3, verbose=True, n_jobs=-1)

# %%
#best_glg=glg.fit(x_train,y_train)

# %%
#best_glg.best_estimator_

# %%
#print (f'Accuracy - : {best_glg.score(x_train,y_train):.3f}')

# %%
# apply logistic regression

lg=LogisticRegression()
lg.fit(x_train,y_train)
predlg=lg.predict(x_test)
print(classification_report(y_test,predlg))
print(confusion_matrix(y_test,predlg))
print(accuracy_score(y_test,predlg))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.03      0.05      5297
#            1       0.88      1.00      0.93     36622
#
#     accuracy                           0.87     41919
#    macro avg       0.75      0.51      0.49     41919
# weighted avg       0.84      0.87      0.82     41919
#
# [[  133  5164]
#  [   83 36539]]
# 0.874830029342303

# %%
# applying AUC ROC for logistic regression
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
y_proba=lg.predict_proba(x_test)

y_proba
# Out:
# array([[2.25028880e-02, 9.77497112e-01],
#        [3.82161823e-01, 6.17838177e-01],
#        [1.68478234e-01, 8.31521766e-01],
#        ...,
#        [4.60636729e-09, 9.99999995e-01],
#        [1.83093470e-01, 8.16906530e-01],
#        [4.07552046e-01, 5.92447954e-01]])

# %%
fpr,tpr,thresholds=roc_curve(y_test,y_proba[:,1])

# %%
fpr
# Out:
# array([0.        , 0.        , 0.        , ..., 0.99981121, 0.99981121,
#        1.        ])

# %%
tpr
# Out:
# array([0.        , 0.00158375, 0.00169297, ..., 0.99994539, 1.        ,
#        1.        ])

# %%
thresholds
# Out:
# array([2.        , 1.        , 1.        , ..., 0.08953054, 0.08025387,
#        0.04300413])

# %%
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr)
plt.title('Logistic regression')
plt.xlabel('false positive rate ')
plt.ylabel('true positive rate')
# Out:
# Text(0, 0.5, 'true positive rate')

# %%
# Applying grid search for decision tree


from sklearn.model_selection import GridSearchCV

# %%
dtc=DecisionTreeClassifier()
grid_param={'criterion':['gini','entropy']}

gd_sr=GridSearchCV(estimator=dtc,param_grid=grid_param,scoring='accuracy',cv=5)
gd_sr.fit(x_train,y_train)

best_para=gd_sr.best_params_
print(best_para)
best_result=gd_sr.best_score_
print(best_result)
# Out:
# {'criterion': 'entropy'}
# 0.8688526728554369

# %%
# applying decision tree with best parameters 

dtc=DecisionTreeClassifier(criterion= 'entropy')

# %%
dtc.fit(x_train,y_train)
pdtc=dtc.predict(x_test)
print(accuracy_score(y_test,pdtc))
print(confusion_matrix(y_test,pdtc))
print(classification_report(y_test,pdtc))
# Out:
# 0.8682459028125671
# [[ 2642  2655]
#  [ 2868 33754]]
#               precision    recall  f1-score   support
#
#            0       0.48      0.50      0.49      5297
#            1       0.93      0.92      0.92     36622
#
#     accuracy                           0.87     41919
#    macro avg       0.70      0.71      0.71     41919
# weighted avg       0.87      0.87      0.87     41919

# %%
# Applying auc roc for decision tree 

dtc_proba=dtc.predict_proba(x_test)
fpr,tpr,thresholds=roc_curve(y_test,dtc_proba[:,1])
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr)
plt.title('decision tree')
plt.xlabel('false positive rate ')
plt.ylabel('true positive rate')
# Out:
# Text(0, 0.5, 'true positive rate')

# %%
auc_score=roc_auc_score(y_test,pdtc)
auc_score
# Out:
# 0.710229654157691

# %%
# Applying grid search for random forest 



# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 10, stop = 80, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [2,4]
# Minimum number of samples required to split a node
min_samples_split = [2, 5]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2]
# Method of selecting samples for training each tree
bootstrap = [True, False]

# %%
# Create the param grid
param_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}
print(param_grid)
# Out:
# {'n_estimators': [10, 17, 25, 33, 41, 48, 56, 64, 72, 80], 'max_features': ['auto', 'sqrt'], 'max_depth': [2, 4], 'min_samples_split': [2, 5], 'min_samples_leaf': [1, 2], 'bootstrap': [True, False]}

# %%
rf_Model = RandomForestClassifier()
from sklearn.model_selection import GridSearchCV
rf_Grid = GridSearchCV(estimator = rf_Model, param_grid = param_grid, cv = 3, verbose=2, n_jobs = 4)
rf_Grid.fit(x_train, y_train)
rf_Grid.best_params_
# Out:
# Fitting 3 folds for each of 320 candidates, totalling 960 fits
# {'bootstrap': True,
#  'max_depth': 4,
#  'max_features': 'auto',
#  'min_samples_leaf': 2,
#  'min_samples_split': 5,
#  'n_estimators': 25}

# %%
print (f'Train Accuracy - : {rf_Grid.score(x_train,y_train):.3f}')
print (f'Test Accuracy - : {rf_Grid.score(x_test,y_test):.3f}')#A pplying r
# Out:
# Train Accuracy - : 0.902
# Test Accuracy - : 0.900

# %%
# I am getting better result with applying normal random forest so i am not using the best parms

# %%
#Applying random forest classifier 
rfc=RandomForestClassifier()

# %%
rfc.fit(x_train,y_train)
prfc=rfc.predict(x_test)
print(accuracy_score(y_test,prfc))
print(confusion_matrix(y_test,prfc))
print(classification_report(y_test,prfc))
# Out:
# 0.9127364679500942
# [[ 2347  2950]
#  [  708 35914]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.44      0.56      5297
#            1       0.92      0.98      0.95     36622
#
#     accuracy                           0.91     41919
#    macro avg       0.85      0.71      0.76     41919
# weighted avg       0.90      0.91      0.90     41919

# %%
# Applying auc roc for random forest 

rfc_proba=rfc.predict_proba(x_test)
fpr,tpr,thresholds=roc_curve(y_test,rfc_proba[:,1])
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr)
plt.title('decision tree')
plt.xlabel('false positive rate ')
plt.ylabel('true positive rate')
# Out:
# Text(0, 0.5, 'true positive rate')

# %%
auc_score=roc_auc_score(y_test,prfc)
auc_score
# Out:
# 0.7118741738288146

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier()
gbc.fit(x_train,y_train)
predg=gbc.predict(x_test)

# %%
print(accuracy_score(y_test,predg))
print(confusion_matrix(y_test,predg))
print(classification_report(y_test,predg))
# Out:
# 0.9075836732746487
# [[ 1867  3430]
#  [  444 36178]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.35      0.49      5297
#            1       0.91      0.99      0.95     36622
#
#     accuracy                           0.91     41919
#    macro avg       0.86      0.67      0.72     41919
# weighted avg       0.90      0.91      0.89     41919

# %%
# The best model is random forest with accuracy of 91%

# %%
# SAVING THE BEST MODEL that is random forest with 82% accuracy

import pickle as pk
file=open('MICRO_CREDIT.pkl','wb')
pk.dump(rfc,file)
