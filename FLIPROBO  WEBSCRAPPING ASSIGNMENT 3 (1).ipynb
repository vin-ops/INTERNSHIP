# %%
from bs4 import BeautifulSoup
import requests
import selenium
import time
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from tqdm import tqdm
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import selenium.webdriver.common.keys

# %% [markdown]
# # Ans1.

# %%
driver=webdriver.Chrome(r'C:/Users/vinay/OneDrive/Desktop/chromedriver.exe')

# %%
page=driver.get('https://www.amazon.in/')

# %%
search_product=driver.find_element_by_id('twotabsearchtextbox') # i inspected it and there is id available so we find it by id 
search_product.send_keys(input('enter product name:'))
# Out:
# enter product name:mobile phone

# %%
search_btn=driver.find_element_by_id("nav-search-submit-button") # search button to start the search 
search_btn.click()

# %% [markdown]
# # * ANS2
# #SCRAPE "Brand Name", "Name of the Product", "Rating", "No. of
# #Ratings", "Price", "Return/Exchange", "Expected Delivery", "Availability", "Other Details","product url"

# %%
url=[]

for page in range(0,3):
    
    for i in driver.find_elements_by_xpath('//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]'):
        url.append(i.get_attribute('href'))
      
    nxt_button=driver.find_element_by_xpath('//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')     
    nxt_button.click()  
    time.sleep(2)

# %%
len(url)
# Out:
# 70

# %%
url[0] # checking the url
# Out:
# 'https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A0041101ZJ6AZTA91LYC&url=%2FKALL-Smartphone-Storage-Volte-Purple%2Fdp%2FB09TRDHJ59%2Fref%3Dsr_1_1_sspa%3Fcrid%3D2F56URWWZGWN9%26keywords%3Dmobile%2Bphone%26qid%3D1647085044%26sprefix%3Dmobile%2B%252Caps%252C525%26sr%3D8-1-spons%26psc%3D1&qualifier=1647085044&id=2470513920633965&widgetName=sp_atf'

# %%
driver=webdriver.Chrome(r'C:/Users/vinay/OneDrive/Desktop/chromedriver.exe')
driver.get(url[0])

# %%
brand=[]

for i in tqdm(url):
    driver.get(i)
    try:
        brand_name=driver.find_element_by_xpath('//tr[@class="a-spacing-small po-brand"]')
        brand.append(brand_name.text)
    except NoSuchElementException:
        
        brand.append('-')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 70/70 [05:44<00:00,  4.92s/it]

# %%
product=[]

for i in tqdm(url):
    driver.get(i)
    try:
        product_name=driver.find_element_by_xpath('//tr[@class="a-spacing-small po-model_name"]')
        product.append(product_name.text)
    except NoSuchElementException:
        
        product.append('-')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 70/70 [05:01<00:00,  4.31s/it]

# %%
ratings=[]

for i in tqdm(url):
    driver.get(i)
    try:
        no_of_rating=driver.find_element_by_xpath('//span[@id="acrCustomerReviewText"]')

        ratings.append(no_of_rating.text)
    except NoSuchElementException:
        
        ratings.append('-')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 70/70 [04:52<00:00,  4.17s/it]

# %%
Price=[]

for i in tqdm(url):
    driver.get(i)
    try:
        price=driver.find_element_by_xpath('//span[@class="a-price a-text-price a-size-medium apexPriceToPay"]')


        Price.append(price.text)
    except NoSuchElementException:
        
        Price.append('-')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 70/70 [04:38<00:00,  3.98s/it]

# %%
Return=[]

for i in url:
    driver.get(i)
    try:
        return_exchange=driver.find_element_by_xpath('//div[@=class="a-section a-spacing-none icon-content"]')


        Return.append(return_exchange.text)
    except NoSuchElementException:
        
        Return.append('-')

# %%
delivery=[]

for i in tqdm(url):
    driver.get(i)
    try:
        expected_delivery=driver.find_element_by_xpath('//div[@class="a-spacing-base"]')


        delivery.append(expected_delivery.text)
    except NoSuchElementException:
        
        delivery.append('-')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 70/70 [04:32<00:00,  3.89s/it]

# %%
Availability=[]

for i in tqdm(url):
    driver.get(i)
    try:
        avaialability=driver.find_element_by_xpath('//span[@class="a-size-medium a-color-success"]')


        Availability.append(avaialability.text)
    except NoSuchElementException:
        
        Availability.append('-')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 70/70 [04:41<00:00,  4.02s/it]

# %%
import pandas as pd 

pd.DataFrame({'BRAND NAME':brand,'PRODUCT NAME':product,'NO OF RATINGS':ratings,'PRICE':Price,'RETURN EXCHANGE':Return,
         'EXPECTED DELIVERY':delivery,'AVAILBILITY':Availability,'PRODUCT URL':url})
# Out:
#        BRAND NAME              PRODUCT NAME   NO OF RATINGS       PRICE  \
# 0     Brand IKALL         Model Name Purple       5 ratings   ₹4,499.00
# 1     Brand IKALL           Model Name Blue        1 rating   ₹4,899.00
# 2      Brand Oppo        Model Name CPH2015  47,788 ratings  ₹12,989.00
# 3     Brand IKALL          Model Name Green        1 rating           -
# 4      Brand Oppo        Model Name CPH2015  47,788 ratings  ₹12,989.00
# ..            ...                       ...             ...         ...
# 65  Brand Samsung  Model Name Galaxy M32 5G  23,629 ratings  ₹20,999.00
# 66     Brand Oppo      Model Name OPPO A15s   2,532 ratings  ₹10,990.00
# 67    Brand IKALL         Model Name Purple        1 rating           -
# 68    Brand Tecno       Model Name Spark 8C     199 ratings   ₹7,799.00
# 69    Brand IKALL           Model Name Grey        1 rating   ₹6,499.00
#
#    RETURN EXCHANGE                           EXPECTED DELIVERY AVAILBILITY  \
# 0                -        FREE delivery: March 17 - 19 Details           -
# 1                -  FREE delivery: Wednesday, March 16 Details   In stock.
# 2                -     FREE delivery: Monday, March 14 Details   In stock.
# 3                -  FREE delivery: Wednesday, March 16 Details   In stock.
# 4                -     FREE delivery: Monday, March 14 Details   In stock.
# ..             ...                                         ...         ...
# 65               -     FREE delivery: Monday, March 14 Details   In stock.
# 66               -     FREE delivery: Monday, March 14 Details   In stock.
# 67               -  FREE delivery: Wednesday, March 16 Details   In stock.
# 68               -   FREE delivery: Saturday, March 26 Details           -
# 69               -  FREE delivery: Wednesday, March 16 Details   In stock.
#
#                                           PRODUCT URL
# 0   https://www.amazon.in/gp/slredirect/picassoRed...
# 1   https://www.amazon.in/gp/slredirect/picassoRed...
# 2   https://www.amazon.in/Oppo-Fantasy-Storage-Add...
# 3   https://www.amazon.in/KALL-Smartphone-Volte-Di...
# 4   https://www.amazon.in/Oppo-Mystery-Storage-Add...
# ..                                                ...
# 65  https://www.amazon.in/Samsung-Galaxy-Blue-128G...
# 66  https://www.amazon.in/Test-TST_Exclusive1003-E...
# 67  https://www.amazon.in/KALL-Smartphone-Volte-Di...
# 68  https://www.amazon.in/gp/slredirect/picassoRed...
# 69  https://www.amazon.in/gp/slredirect/picassoRed...
#
# [70 rows x 8 columns]

# %% [markdown]
# # ANS3

# %%
driver=webdriver.Chrome(r'C:/Users/vinay/OneDrive/Desktop/chromedriver.exe')

time.sleep(3)

page=driver.get("https://images.google.com/")

# %%
search_bar = driver.find_element_by_xpath('//input[@class="gLFyf gsfi"]')   
search_bar.send_keys("fruits")    
search_button = driver.find_element_by_xpath('//span[@class="z1asCe MZy1Rb"]')    
search_button.click()

# %%
for _ in range(500):
    driver.execute_script("window.scrollBy(0,10000)")
    
images = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
            
for i in range(len(img_urls)):
    if i >= 100:
        break
    print("Downloading {0} of {1} images" .format(i, 100))
    response= requests.get(img_urls[i])
    file = open(r"C:\Users\vinay\OneDrive\Desktop\fliprobo"+str(i)+".jpg", "wb")
    file.write(response.content)
# Out:
# Downloading 0 of 100 images
# Downloading 1 of 100 images
# Downloading 2 of 100 images
# Downloading 3 of 100 images
# Downloading 4 of 100 images
# Downloading 5 of 100 images
# Downloading 6 of 100 images
# Downloading 7 of 100 images
# Downloading 8 of 100 images
# Downloading 9 of 100 images
# Downloading 10 of 100 images
# Downloading 11 of 100 images
# Downloading 12 of 100 images
# Downloading 13 of 100 images
# Downloading 14 of 100 images
# Downloading 15 of 100 images
# Downloading 16 of 100 images
# Downloading 17 of 100 images
# Downloading 18 of 100 images
# Downloading 19 of 100 images
# Downloading 20 of 100 images
# Downloading 21 of 100 images
# Downloading 22 of 100 images
# Downloading 23 of 100 images
# Downloading 24 of 100 images
# Downloading 25 of 100 images
# Downloading 26 of 100 images
# Downloading 27 of 100 images
# Downloading 28 of 100 images
# Downloading 29 of 100 images
# Downloading 30 of 100 images
# Downloading 31 of 100 images
# Downloading 32 of 100 images
# Downloading 33 of 100 images
# Downloading 34 of 100 images
# Downloading 35 of 100 images
# Downloading 36 of 100 images
# Downloading 37 of 100 images
# Downloading 38 of 100 images
# Downloading 39 of 100 images
# Downloading 40 of 100 images
# Downloading 41 of 100 images
# Downloading 42 of 100 images
# Downloading 43 of 100 images
# Downloading 44 of 100 images

# %% [markdown]
# # ANS4.

# %%
driver=webdriver.Chrome(r'C:/Users/vinay/OneDrive/Desktop/chromedriver.exe')


page=driver.get('https://www.flipkart.com/')

# %%
try:
    login_cross_button = driver.find_element_by_xpath('//button[@class="_2KpZ6l _2doB4z"]')  # Button to close login popup
    login_cross_button.click()
except NoSuchElementException : 
    print("No Login page")

# %%
search_bar = driver.find_element_by_xpath('//input[@class="_3704LK"]')  
search_bar.send_keys("samsung A20")   
click_search=driver.find_element_by_xpath('//button[@class="L0Z3Pu"]')

click_search.click()

# %%
phone_urls=[]

urls = driver.find_elements_by_xpath('//a[@class="_1fQZEK"]')
for url in urls:
    phone_urls.append(url.get_attribute('href'))

# %%
flip_dict = {}
flip_dict["Brand"] = []
flip_dict["Smartphone"] = []
flip_dict["Colour"] = []
flip_dict["RAM"] = []
flip_dict["Storage(ROM)"] = []
flip_dict["Primary Camera"] = []
flip_dict["Secondary Camera"] = []
flip_dict["Display Size"] = []
flip_dict["Display Resolution"] = []
flip_dict["Processor"] = []
flip_dict["Processor Cores"] = []
flip_dict["Battery Capacity"] = []
flip_dict["Battery Type"] = []
flip_dict["Price"] = []
flip_dict["URL"] = []

# %%
for url in phone_urls:
    driver.get(url)                                                        
    print("Scraping URL = ", url)
    flip_dict['URL'].append(url)
# Out:
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-a20-black-32-gb/p/itmffag4tzdhzubq?pid=MOBFFAG4YPASHGEB&lid=LSTMOBFFAG4YPASHGEBBBAESB&marketplace=FLIPKART&q=samsung+A20&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=Search&iid=f85ba86c-0a30-418f-a4d3-8fa4cf0e4530.MOBFFAG4YPASHGEB.SEARCH&ppt=hp&ppn=homepage&ssid=b85dt0cqio0000001648132574455&qH=ac4992afd99186f7
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-a20-deep-blue-32-gb/p/itmffag4fpdgcguy?pid=MOBFFAG4C5CZF4VN&lid=LSTMOBFFAG4C5CZF4VNK5XMS6&marketplace=FLIPKART&q=samsung+A20&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=Search&iid=f85ba86c-0a30-418f-a4d3-8fa4cf0e4530.MOBFFAG4C5CZF4VN.SEARCH&ppt=hp&ppn=homepage&ssid=b85dt0cqio0000001648132574455&qH=ac4992afd99186f7
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-a20-red-32-gb/p/itmffag4kg6zzrca?pid=MOBFFAG46KYERGRF&lid=LSTMOBFFAG46KYERGRFNAQRNR&marketplace=FLIPKART&q=samsung+A20&store=tyy%2F4io&srno=s_1_3&otracker=search&otracker1=search&fm=Search&iid=f85ba86c-0a30-418f-a4d3-8fa4cf0e4530.MOBFFAG46KYERGRF.SEARCH&ppt=hp&ppn=homepage&ssid=b85dt0cqio0000001648132574455&qH=ac4992afd99186f7
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-a20-gold-32-gb/p/itmfhhqg5mxczxc9?pid=MOBFHCRGDFASPZRA&lid=LSTMOBFHCRGDFASPZRAME3JHK&marketplace=FLIPKART&q=samsung+A20&store=tyy%2F4io&srno=s_1_4&otracker=search&otracker1=search&fm=Search&iid=f85ba86c-0a30-418f-a4d3-8fa4cf0e4530.MOBFHCRGDFASPZRA.SEARCH&ppt=hp&ppn=homepage&ssid=b85dt0cqio0000001648132574455&qH=ac4992afd99186f7
# Scraping URL =  https://www.flipkart.com/samsung-s20-fe-5g-cloud-navy-128-gb/p/itm7e60663e03f3f?pid=MOBG47FEDRWHUCKF&lid=LSTMOBG47FEDRWHUCKFLNL91G&marketplace=FLIPKART&q=samsung+A20&store=tyy%2F4io&srno=s_1_5&otracker=search&otracker1=search&fm=Search&iid=f85ba86c-0a30-418f-a4d3-8fa4cf0e4530.MOBG47FEDRWHUCKF.SEARCH&ppt=hp&ppn=homepage&ssid=b85dt0cqio0000001648132574455&qH=ac4992afd99186f7
# Scraping URL =  https://www.flipkart.com/samsung-s20-fe-5g-cloud-mint-128-gb/p/itm45d522d270f0d?pid=MOBG8X8PTHRRHSKG&lid=LSTMOBG8X8PTHRRHSKGPVDQOQ&marketplace=FLIPKART&q=samsung+A20&store=tyy%2F4io&srno=s_1_6&otracker=search&otracker1=search&fm=Search&iid=f85ba86c-0a30-418f-a4d3-8fa4cf0e4530.MOBG8X8PTHRRHSKG.SEARCH&ppt=hp&ppn=homepage&ssid=b85dt0cqio0000001648132574455&qH=ac4992afd99186f7
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-a20s-black-64-gb/p/itm031a57b9d6b08?pid=MOBFKKGRPQDS98WH&lid=LSTMOBFKKGRPQDS98WH92IIKL&marketplace=FLIPKART&q=samsung+A20&store=tyy%2F4io&srno=s_1_7&otracker=search&otracker1=search&fm=Search&iid=f85ba86c-0a30-418f-a4d3-8fa4cf0e4530.MOBFKKGRPQDS98WH.SEARCH&ppt=hp&ppn=homepage&ssid=b85dt0cqio0000001648132574455&qH=ac4992afd99186f7
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-a20s-black-32-gb/p/itm3e7775c40a2f8?pid=MOBFKKGRTHKTGUSS&lid=LSTMOBFKKGRTHKTGUSSQ639A4&marketplace=FLIPKART&q=samsung+A20&store=tyy%2F4io&srno=s_1_8&otracker=search&otracker1=search&fm=Search&iid=f85ba86c-0a30-418f-a4d3-8fa4cf0e4530.MOBFKKGRTHKTGUSS.SEARCH&ppt=hp&ppn=homepage&ssid=b85dt0cqio0000001648132574455&qH=ac4992afd99186f7
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-s20-fe-cloud-navy-128-gb/p/itm64424c1cc5af2?pid=MOBFWAVTQNMETGGG&lid=LSTMOBFWAVTQNMETGGGOMTMOC&marketplace=FLIPKART&q=samsung+A20&store=tyy%2F4io&srno=s_1_9&otracker=search&otracker1=search&fm=Search&iid=f85ba86c-0a30-418f-a4d3-8fa4cf0e4530.MOBFWAVTQNMETGGG.SEARCH&ppt=hp&ppn=homepage&ssid=b85dt0cqio0000001648132574455&qH=ac4992afd99186f7
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-a20s-green-32-gb/p/itm8d67a186289e8?pid=MOBFKKGRKBTNANRH&lid=LSTMOBFKKGRKBTNANRH1FUWV7&marketplace=FLIPKART&q=samsung+A20&store=tyy%2F4io&srno=s_1_10&otracker=search&otracker1=search&fm=Search&iid=f85ba86c-0a30-418f-a4d3-8fa4cf0e4530.MOBFKKGRKBTNANRH.SEARCH&ppt=hp&ppn=homepage&ssid=b85dt0cqio0000001648132574455&qH=ac4992afd99186f7
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-a20s-blue-64-gb/p/itmc4b81e2436fe6?pid=MOBFKKGRGA3E2PYP&lid=LSTMOBFKKGRGA3E2PYP074YMN&marketplace=FLIPKART&q=samsung+A20&store=tyy%2F4io&srno=s_1_11&otracker=search&otracker1=search&fm=Search&iid=f85ba86c-0a30-418f-a4d3-8fa4cf0e4530.MOBFKKGRGA3E2PYP.SEARCH&ppt=hp&ppn=homepage&ssid=b85dt0cqio0000001648132574455&qH=ac4992afd99186f7
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-a20s-blue-32-gb/p/itmf6f28dfda35a8?pid=MOBFKKGRNXCA4FTW&lid=LSTMOBFKKGRNXCA4FTWGKK7ZB&marketplace=FLIPKART&q=samsung+A20&store=tyy%2F4io&srno=s_1_12&otracker=search&otracker1=search&fm=Search&iid=f85ba86c-0a30-418f-a4d3-8fa4cf0e4530.MOBFKKGRNXCA4FTW.SEARCH&ppt=hp&ppn=homepage&ssid=b85dt0cqio0000001648132574455&qH=ac4992afd99186f7
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-a32-awesome-blue-128-gb/p/itmc6020edc16c84?pid=MOBG8TZHYYQYGUBG&lid=LSTMOBG8TZHYYQYGUBGETZUHD&marketplace=FLIPKART&q=samsung+A20&store=tyy%2F4io&srno=s_1_13&otracker=search&otracker1=search&fm=Search&iid=f85ba86c-0a30-418f-a4d3-8fa4cf0e4530.MOBG8TZHYYQYGUBG.SEARCH&ppt=hp&ppn=homepage&ssid=b85dt0cqio0000001648132574455&qH=ac4992afd99186f7
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-s20-ultra-cosmic-gray-128-gb/p/itma25b4687846b4?pid=MOBFZXZ22CWZ2JZB&lid=LSTMOBFZXZ22CWZ2JZB7GKWML&marketplace=FLIPKART&q=samsung+A20&store=tyy%2F4io&srno=s_1_14&otracker=search&otracker1=search&fm=Search&iid=f85ba86c-0a30-418f-a4d3-8fa4cf0e4530.MOBFZXZ22CWZ2JZB.SEARCH&ppt=hp&ppn=homepage&ssid=b85dt0cqio0000001648132574455&qH=ac4992afd99186f7
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-s20-fe-cloud-mint-128-gb/p/itm08c6a49fe2661?pid=MOBFWAVTKRH6GFQG&lid=LSTMOBFWAVTKRH6GFQGUHWBYV&marketplace=FLIPKART&q=samsung+A20&store=tyy%2F4io&srno=s_1_15&otracker=search&otracker1=search&fm=Search&iid=f85ba86c-0a30-418f-a4d3-8fa4cf0e4530.MOBFWAVTKRH6GFQG.SEARCH&ppt=hp&ppn=homepage&ssid=b85dt0cqio0000001648132574455&qH=ac4992afd99186f7
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-s20-fe-cloud-white-128-gb/p/itm43c3c96db2180?pid=MOBFWAVTMGYNUDHW&lid=LSTMOBFWAVTMGYNUDHW6E1W6T&marketplace=FLIPKART&q=samsung+A20&store=tyy%2F4io&srno=s_1_16&otracker=search&otracker1=search&fm=Search&iid=f85ba86c-0a30-418f-a4d3-8fa4cf0e4530.MOBFWAVTMGYNUDHW.SEARCH&ppt=hp&ppn=homepage&ssid=b85dt0cqio0000001648132574455&qH=ac4992afd99186f7
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-m20-ocean-blue-64-gb/p/itmfe4bfyznwhzsg?pid=MOBFE7VRHSYJEGSQ&lid=LSTMOBFE7VRHSYJEGSQER5EH0&marketplace=FLIPKART&q=samsung+A20&store=tyy%2F4io&srno=s_1_17&otracker=search&otracker1=search&fm=Search&iid=f85ba86c-0a30-418f-a4d3-8fa4cf0e4530.MOBFE7VRHSYJEGSQ.SEARCH&ppt=hp&ppn=homepage&ssid=b85dt0cqio0000001648132574455&qH=ac4992afd99186f7
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-note-20-mystic-green-256-gb/p/itm38acf149a4551?pid=MOBFU5WYVAAGDCGW&lid=LSTMOBFU5WYVAAGDCGWKJD8SS&marketplace=FLIPKART&q=samsung+A20&store=tyy%2F4io&srno=s_1_18&otracker=search&otracker1=search&fm=Search&iid=f85ba86c-0a30-418f-a4d3-8fa4cf0e4530.MOBFU5WYVAAGDCGW.SEARCH&ppt=hp&ppn=homepage&ssid=b85dt0cqio0000001648132574455&qH=ac4992afd99186f7
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-note-20-ultra-5g-mystic-bronze-256-gb/p/itm33ee94e816ae4?pid=MOBFU5WY7UFG4KD9&lid=LSTMOBFU5WY7UFG4KD9Q7ZZJ2&marketplace=FLIPKART&q=samsung+A20&store=tyy%2F4io&srno=s_1_19&otracker=search&otracker1=search&fm=Search&iid=f85ba86c-0a30-418f-a4d3-8fa4cf0e4530.MOBFU5WY7UFG4KD9.SEARCH&ppt=hp&ppn=homepage&ssid=b85dt0cqio0000001648132574455&qH=ac4992afd99186f7
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-note-20-mystic-bronze-256-gb/p/itm145aeec4730f5?pid=MOBFU5WYMX5Y8YCY&lid=LSTMOBFU5WYMX5Y8YCYK1M7UA&marketplace=FLIPKART&q=samsung+A20&store=tyy%2F4io&srno=s_1_20&otracker=search&otracker1=search&fm=Search&iid=f85ba86c-0a30-418f-a4d3-8fa4cf0e4530.MOBFU5WYMX5Y8YCY.SEARCH&ppt=hp&ppn=homepage&ssid=b85dt0cqio0000001648132574455&qH=ac4992afd99186f7
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-note-20-ultra-5g-mystic-black-256-gb/p/itm92ef5350e448d?pid=MOBFU5WYPMCGAZ6J&lid=LSTMOBFU5WYPMCGAZ6JTZLDGQ&marketplace=FLIPKART&q=samsung+A20&store=tyy%2F4io&srno=s_1_21&otracker=search&otracker1=search&fm=Search&iid=f85ba86c-0a30-418f-a4d3-8fa4cf0e4530.MOBFU5WYPMCGAZ6J.SEARCH&ppt=hp&ppn=homepage&ssid=b85dt0cqio0000001648132574455&qH=ac4992afd99186f7
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-a20s-green-64-gb/p/itmaf4056b5ecee4?pid=MOBFKKGRAC5NQH97&lid=LSTMOBFKKGRAC5NQH975IEPUC&marketplace=FLIPKART&q=samsung+A20&store=tyy%2F4io&srno=s_1_22&otracker=search&otracker1=search&fm=Search&iid=f85ba86c-0a30-418f-a4d3-8fa4cf0e4530.MOBFKKGRAC5NQH97.SEARCH&ppt=hp&ppn=homepage&ssid=b85dt0cqio0000001648132574455&qH=ac4992afd99186f7
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-m20-charcoal-black-64-gb/p/itmfe4bfyznwhzsg?pid=MOBFEAP5YPYMYCNZ&lid=LSTMOBFEAP5YPYMYCNZUWBF8F&marketplace=FLIPKART&q=samsung+A20&store=tyy%2F4io&srno=s_1_23&otracker=search&otracker1=search&fm=Search&iid=f85ba86c-0a30-418f-a4d3-8fa4cf0e4530.MOBFEAP5YPYMYCNZ.SEARCH&ppt=hp&ppn=homepage&ssid=b85dt0cqio0000001648132574455&qH=ac4992afd99186f7
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-note-20-mystic-blue-256-gb/p/itm02d10969ce115?pid=MOBFUKHDNAZGZUAZ&lid=LSTMOBFUKHDNAZGZUAZOB3TDS&marketplace=FLIPKART&q=samsung+A20&store=tyy%2F4io&srno=s_1_24&otracker=search&otracker1=search&fm=Search&iid=f85ba86c-0a30-418f-a4d3-8fa4cf0e4530.MOBFUKHDNAZGZUAZ.SEARCH&ppt=hp&ppn=homepage&ssid=b85dt0cqio0000001648132574455&qH=ac4992afd99186f7

# %%
try:
    read_more=driver.find_element_by_xpath('//button[@class="_2KpZ6l _1FH0tX"]')
    read_more.click()
    
    
except NoSuchElementException:
        print("Exception Occured. Moving to next page")

# %%
try:
    
    brand = driver.find_element_by_xpath('//span[@class="B_NuCI"]')      # Extracting Brand from xpath
    flip_dict["Brand"].append(brand.text.split()[0])
except NoSuchElementException:
    
    flip_dict['Brand'].append('-')

# %%
try:
    price = driver.find_element_by_xpath('//div[@class="_30jeq3 _16Jk6d"]')      # Extracting Price from xpath
    flip_dict['Price'].append(price.text)
except NoSuchElementException:
    flip_dict['Price'].append('-')

# %%
 try:
    name = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][1]/table/tbody/tr[3]/td[2]/ul/li')      # Extracting Name from xpath
    flip_dict['Smartphone'].append(name.text)
except NoSuchElementException:
    flip_dict['Smartphone'].append('-')
    
try:
    color = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][1]/table/tbody/tr[4]/td[2]/ul/li')      # Extracting colour from xpath
    flip_dict['Colour'].append(color.text)
except NoSuchElementException:
    flip_dict['Colour'].append('-')
   
   
try:
        
    disp_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"]')
    if disp_chk.text != "Display Features" : raise NoSuchElementException
        
    disp_size = driver.find_element_by_xpath('//td[@class="_1hKmbr col col-3-12"]')  
    flip_dict['Display Size'].append(disp_size.text)
except NoSuchElementException:
    flip_dict['Display Size'].append('-')
        
flip_dict['Display Size']
# Out:
# ['-']

# %%
try:
    disp_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][2]/div')
    if disp_chk.text != "Display Features" : raise NoSuchElementException
    
    disp_res = driver.find_element_by_xpath('//li[@class="_21lJbe"]')  
    flip_dict['Display Resolution'].append(disp_res.text)
except NoSuchElementException:
    flip_dict['Display Resolution'].append('-')
    

    
try:
    pro_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][3]/table[1]/tbody/tr[2]/td[1]')
    if pro_chk.text != "Processor Type" : raise NoSuchElementException
    processor = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][3]/table[1]/tbody/tr[2]/td[2]/ul/li')   
    flip_dict["Processor"].append(processor.text)
except NoSuchElementException:
    flip_dict["Processor"].append('-')    
flip_dict["Processor"] 

try:
    core_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][3]/table[1]/tbody/tr[3]/td[1]')
    if core_chk.text != "Processor Core" :
        core_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][3]/table[1]/tbody/tr[2]/td[1]')
        if core_chk.text != "Processor Core" : 
                raise NoSuchElementException
        else :
            cores = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][3]/table[1]/tbody/tr[2]/td[2]/ul/li')
    else :
        cores = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][3]/table[1]/tbody/tr[3]/td[2]/ul/li')
        flip_dict['Processor Cores'].append(cores.text)
except NoSuchElementException:
    flip_dict['Processor Cores'].append('-')

# %% [markdown]
# # Ans 5

# %%
driver=driver=webdriver.Chrome(r'C:/Users/vinay/OneDrive/Desktop/chromedriver.exe')
time.sleep(2)

page=driver.get("https://www.google.co.in/maps")

time.sleep(2)

# %%
search=driver.find_element_by_id("searchboxinput")

search.send_keys('new delhi')

click=driver.find_element_by_id("searchbox-searchbutton")    

click.click()

# %% [markdown]
# # ANS6

# %%
driver=webdriver.Chrome(r'C:/Users/vinay/OneDrive/Desktop/chromedriver.exe')
time.sleep(2)

page=driver.get('https://trak.in/')
time.sleep(2)

# %%
button = driver.find_element_by_xpath('//li[@id="menu-item-51510"]/a').get_attribute('href')
driver.get(button)

# %%
fund_dict = {}
fund_dict['Date'] = []
fund_dict['Startup Name'] = []
fund_dict['Industry/Vertical'] = []
fund_dict['Sub-Vertical'] = []
fund_dict['Location'] = []
fund_dict['Investor'] = []
fund_dict['Investment Type'] = []
fund_dict['Amount(in USD)'] = []

# %%
for i in range(48,51):
# date
    date=driver.find_elements_by_xpath('//td[@class="column-2"]'.format(i))
    for d in date:
        fund_dict['Date'].append(d.text)
        

# Startup Name
    startup = driver.find_elements_by_xpath('//td[@class="column-3"]'.format(i))
    for n in startup:
        fund_dict['Startup Name'].append(n.text) 
        
# Industry/Vertical

    industry = driver.find_elements_by_xpath('//td[@class="column-4"]'.format(i))
    for n in industry:
        fund_dict['Industry/Vertical'].append(n.text)
        
     # Sub-Vertical
    sv = driver.find_elements_by_xpath('//td[@class="column-5"]'.format(i))
    for s in sv:
        fund_dict['Sub-Vertical'].append(s.text)

    # Location
    loc = driver.find_elements_by_xpath('//td[@class="column-6"]'.format(i))
    for l in loc:
        fund_dict['Location'].append(l.text)
    
    # Investor
    inv = driver.find_elements_by_xpath('//td[@class="column-7"]'.format(i))
    for n in inv:
        fund_dict['Investor'].append(n.text)
    
    # Investment Type
    invt = driver.find_elements_by_xpath('//td[@class="column-8"]'.format(i))
    for n in invt:
        fund_dict['Investment Type'].append(n.text)
    
    # Amount
    amt = driver.find_elements_by_xpath('//td[@class="column-9"]'.format(i))
    for a in amt:
        fund_dict['Amount(in USD)'].append(a.text)

# %%
fund_dict['Date']=fund_dict['Date'][0:1177]

fund_dict['Startup Name']=fund_dict['Startup Name'][0:1177]
 
fund_dict['Industry/Vertical']=fund_dict['Industry/Vertical'][0:1177]

# %%
import pandas as pd 

df=pd.DataFrame(fund_dict)
df
# Out:
#             Date    Startup Name     Industry/Vertical  \
# 0     01/04/2021          BYJU’S              Edu-tech
# 1     05/04/2021          Meesho            E-commerce
# 2     14/04/2021          Swiggy  Online Food Delivery
# 3     07/04/2021           Groww               FinTech
# 4     14/04/2021         Beldara            E-commerce
# ...          ...             ...                   ...
# 1171  09/07/2018        zippserv     Consumer Internet
# 1172  09/07/2018           Groww     Consumer Internet
# 1173  10/07/2018   Avenue Growth     Consumer Internet
# 1174  10/07/2018           iNICU            Healthcare
# 1175  10/07/2018  Kinara Capital               Finance
#
#                                            Sub-Vertical   Location  \
# 0                                       Online tutoring  Bengaluru
# 1                             Online reselling platform  Bengaluru
# 2                                  Online Food Delivery  Bengaluru
# 3                                   Investment platform  Bengaluru
# 4                                Global B2B marketplace     Mumbai
# ...                                                 ...        ...
# 1171  Online Platform For Risk-Assessment Services F...  Bengaluru
# 1172  Online Platform That Sells Direct Plans Of Mut...  Bengaluru
# 1173  Online Platform That Connects Brands With Free...   Gurugram
# 1174      Med-tech Platform Providing Care For Newborns      Delhi
# 1175   Lending Platform For Micro and Small Enterprises  Bengaluru
#
#                                                Investor      Investment Type  \
# 0                                       Innoven Capital             Series F
# 1                                SoftBank Vision Fund 2             Series E
# 2     Amansa Holdings, Carmignac, Falcon Edge Capita...             Series J
# 3            MC Global Edtech, B Capital, Baron, others             Series D
# 4                              Hindustan Media Ventures              Venture
# ...                                                 ...                  ...
# 1171                              Info Edge (India) Ltd  Seed/ Angel Funding
# 1172  Insignia Ventures Partners, Lightbridge Partne...  Seed/ Angel Funding
# 1173  Avtar Monga, chief operating office at IDFC Ba...  Seed/ Angel Funding
# 1174                                  Venture Catalysts  Seed/ Angel Funding
# 1175                                     ResponsAbility       Private Equity
#
#      Amount(in USD)
# 0       460,000,000
# 1       300,000,000
# 2       343,000,000
# 3        83,000,000
# 4         7,400,000
# ...             ...
# 1171        440,000
# 1172      1,100,000
# 1173        437,000
# 1174            N/A
# 1175      5,000,000
#
# [1176 rows x 8 columns]

# %% [markdown]
# # Ans 7

# %%
driver=webdriver.Chrome(r'C:/Users/vinay/OneDrive/Desktop/chromedriver.exe')


page=driver.get('https://www.digit.in/')

# %%
to_10=driver.find_element_by_xpath('/html/body/div[1]/div/div[4]/ul/li[4]/a')
to_10.click()

# %%
laptops=driver.find_element_by_xpath("/html/body/div[3]/div/div/div[2]/div[5]/div[1]/div/button[2]")
laptops.click()

# %%
best_gaming=driver.find_element_by_xpath("//div[@id='laptops']//div[3]//a")  #taking out links for gaming laptops 
driver.get(best_gaming.get_attribute('href'))

# %%
# empty list 
name = []
Price = []
OS = []
display = []
HDD = []
RAM = []
weight = []
dimension = []
GPU = []

# %%
names=driver.find_elements_by_xpath("//div[@class='right-container']/div/a/h3")
for i in names:
    name.append(i.text)

#scraping operating system
os=driver.find_elements_by_xpath("//div[@class='product-detail']/div/ul/li[1]/div/div")
for i in os:
    OS.append(i.text)

#scraping display
displays=driver.find_elements_by_xpath("//div[@class='product-detail']/div/ul/li[2]/div/div")
for i in displays:
    display.append(i.text)



# scraping memory
memories=driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[6]/td[3]")# extrat HDD and RAM form xpath
for i in memories:
    HDD.append(i.text.split("/")[0])
    RAM.append(i.text.split("/")[1])

# scraping weight
weights=driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[7]/td[3]")# extrat weight form xpath
for i in weights:
    weight.append(i.text)

# scraping dimension

dimensions=driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[8]/td[3]") 
for i in dimensions:
    dimension.append(i.text)

# scraping graphical processor
GPUs=driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[9]/td[3]") 
for i in GPUs:
    GPU.append(i.text)


#scraping price
price=driver.find_elements_by_xpath("//table[@id='summtable']//tr//td[3]")
for i in price:
    Price.append(i.text)

#Make data frame
df=pd.DataFrame({"Name":name,
                "price":Price,
                "OS":OS,
                "Display":display,
                "HDD":HDD,
                 "RAM":RAM,
    
                "weight":weight,
                "Dimension":dimension,
                "Graphical processor":GPU})
df.head(10)
# Out:
#                           Name      price               OS  \
# 0                 HP VICTUS 16  ₹ 104,990       WINDOWS 10
# 1                   HP OMEN 15  ₹ 110,790  WINDOWS 10 HOME
# 2                 ACER NITRO 5  ₹ 129,990       WINDOWS 10
# 3              MSI STEALTH 15M  ₹ 134,990       WINDOWS 10
# 4       ASUS ROG STRIX SCAR 15  ₹ 193,990       WINDOWS 10
# 5       ASUS ROG STRIX SCAR 15  ₹ 215,990  WINDOWS 10 HOME
# 6            ASUS ZEPHYRUS G14  ₹ 144,990  WINDOWS 10 HOME
# 7             LENOVO LEGION 5I   ₹ 76,988   WINDOWS 10 PRO
# 8     ASUS ROG ZEPHYRUS DUO 15  ₹ 185,000       WINDOWS 10
# 9  ACER ASPIRE 7 GAMING LAPTOP   ₹ 53,490  WINDOWS 10 HOME
#
#                Display         HDD           RAM weight  \
# 0  16.1" (1920 X 1200)  512 GB SSD  16 GBGB DDR4   2.48
# 1  15.6" (1920 X 1080)    1 TB SSD  16 GBGB DDR4   2.37
# 2  15.6" (1920 X 1080)    1 TB HDD  16 GBGB DDR4    2.4
# 3  15.6" (1920 X 1080)    1 TB SSD  16 GBGB DDR4    1.7
# 4  15.6" (2560 X 1440)    2 TB SSD  32 GBGB DDR4   2.30
# 5  15.6" (1920 X 1080)    1 TB SSD  16 GBGB DDR4   2.30
# 6    14" (1920 X 1080)    1 TB SSD  16 GBGB DDR4   1.65
# 7  15.6" (1920 X 1080)    1 TB SSD  16 GBGB DDR4    2.3
# 8  15.6" (3840 X 1100)  512 GB SSD   4 GBGB DDR4    2.4
# 9  15.6" (1920 X 1080)  512 GB SSD   8 GBGB DDR4   2.15
#
#                  Dimension            Graphical processor
# 0          37 x 26.2 x 2.4        NVIDIA GeForce RTX 3060
# 1     357.9 x 239.7 x 22.5        NVIDIA GeForce RTX 3060
# 2       363.4 x 255 x 23.9        NVIDIA GeForce RTX 3070
# 3      358.3 x 248 x 16.15        NVIDIA GeForce RTX 3060
# 4         354 x 259 x 22.6        NVIDIA GeForce RTX 3080
# 5       35.4 x 25.9 x 2.26      NVIDIA® GeForce RTX™ 3070
# 6        32.5 x 22.1 x 1.8        NVIDIA GeForce RTX 2060
# 7  363.06 x 259.61 x 23.57  NVIDIA® GeForce® GTX 1650 4GB
# 8  268.30 x 360.00 x 20.90  NVIDIA GeForce RTX 2070 Max-Q
# 9       2.29 x 36.3 x 25.4      NVIDIA® GeForce® GTX 1650

# %%
len(GPU)
# Out:
# 10

# %% [markdown]
# # ANS 8

# %%
driver=webdriver.Chrome(r'C:/Users/vinay/OneDrive/Desktop/chromedriver.exe')
time.sleep(2)

page=driver.get("https://www.forbes.com/?sh=69e6b8c92254")
time.sleep(2)

# %%
# select the explore button 

explore=driver.find_element_by_xpath('//button[@class="icon--hamburger"]')
explore.click()

# %%
#select billionare

billion=driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]")
billion.click()

# %%
#select world billioners 
world_billioners= driver.find_element_by_xpath('/html/body/div[1]/header/nav/div[3]/ul/li[1]/div[2]/ul/li[2]/a')
world_billioners.click()

# %%
#make empty listes
Rank = [] 
Person_Name = [] 
total_net_worth = [] 
Age = []
country_of_citizenship = [] 
Source = []
industry = []

# %%
    #scraping rank of billionaire
    rank= driver.find_elements_by_xpath("//div[@class='rank']")
    for i in rank:
        Rank.append(i.text)
        time.sleep(1)


    name= driver.find_elements_by_xpath("//div[@class='personName']//div")
    for i in name:
        Person_Name.append(i.text)
        time.sleep(1)
    
    #scraping Age of billionaire
    age= driver.find_elements_by_xpath("//div[@class='age']//div")
    for i in age:
        Age.append(i.text)   
        time.sleep(1)
    
#scraping citizenship of billionaire    
    citizenship= driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
    for i in citizenship:
        country_of_citizenship.append(i.text)
        time.sleep(1)
    
#scraping source of income
    source= driver.find_elements_by_xpath("//div[@class='source']")
    for i in source:
        Source.append(i.text)    
        time.sleep(1)

#scraping Age of billionaire
    industries= driver.find_elements_by_xpath("//div[@class='category']//div")
    for i in industries:
        industry.append(i.text)
        time.sleep(1)    
#scraping net_worth of billionaire
    net_worth= driver.find_elements_by_xpath("//div[@class='netWorth']//div[1]")
    for i in net_worth:
        total_net_worth.append(i.text)
        time.sleep(1)    
    
    
                                      
                                      
Net_Worth = []        
for i in range(0,len(total_net_worth),2):
        Net_Worth.append(total_net_worth[i])
    

time.sleep(2)

# %%
Rank=Rank[0:196]
Person_Name=Person_Name[0:196]
Net_Worth=Net_Worth[0:196]
Age=Age[0:196]
country_of_citizenship=country_of_citizenship[0:196]
Source=Source[0:196]
industry=industry[0:196]

# %%
len(industry)
# Out:
# 196

# %%
#creating dataframe
df=pd.DataFrame({'Rank':Rank,
                'Name':Person_Name,
                'Net Worth':Net_Worth,
                'Age':Age,
                'Country of Citizenship':country_of_citizenship,
                'Source':Source,
                'Industry':industry})
df
# Out:
#      Rank                   Name Net Worth Age Country of Citizenship  \
# 0      5.        Mark Zuckerberg     $97 B  36          United States
# 1      6.         Warren Buffett     $96 B  90          United States
# 2      7.          Larry Ellison     $93 B  76          United States
# 3      8.             Larry Page   $91.5 B  48          United States
# 4      9.            Sergey Brin     $89 B  47          United States
# ..    ...                    ...       ...  ..                    ...
# 191  195.        Harry Triguboff   $11.2 B  88                  Chile
# 192  197.  Leonid Fedun & family   $11.1 B  65                  China
# 193  197.              Eyal Ofer   $11.1 B  70              Singapore
# 194  197.           Evan Spiegel   $11.1 B  30                  China
# 195  200.  Luis Carlos Sarmiento     $11 B  88                 Russia
#
#                     Source               Industry
# 0                 Facebook             Technology
# 1       Berkshire Hathaway  Finance & Investments
# 2                 software             Technology
# 3                   Google             Technology
# 4                   Google             Technology
# ..                     ...                    ...
# 191            real estate            Real Estate
# 192                    oil                 Energy
# 193  real estate, shipping            Diversified
# 194               Snapchat             Technology
# 195                banking  Finance & Investments
#
# [196 rows x 7 columns]

# %% [markdown]
# # ANS 9

# %%
# Activating the chrome browser
driver=webdriver.Chrome(r'C:/Users/vinay/OneDrive/Desktop/chromedriver.exe')
time.sleep(2)

# Opening the youtube.com
url = "https://www.youtube.com/"
driver.get(url)
time.sleep(2)

# %%
search_bar = driver.find_element_by_xpath('/html/body/ytd-app/div[1]/div/ytd-masthead/div[3]/div[2]/ytd-searchbox/form/div[1]/div[1]/input')
search_bar.send_keys("kashmir files publec review")  #entering Video name
time.sleep(1)

# %%
#clicking on search button
search_btn = driver.find_element_by_id("search-icon-legacy")  
search_btn.click()
time.sleep(1)

# %%
link_click = driver.find_element_by_xpath('/html/body/ytd-app/div[1]/ytd-page-manager/ytd-search/div[1]/ytd-two-column-search-results-renderer/div/ytd-section-list-renderer/div[2]/ytd-item-section-renderer/div[3]/ytd-video-renderer[10]/div[1]/div/div[1]/div/h3/a/yt-formatted-string')
link_click.click()

# %%
# 1000 time we scroll down by 10000 in order to generate more Comments
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,10000)")

# %%
#make empty lists
comments = []
comment_time = []
Time = []
Likes = []
No_of_Likes = []


try:
    read=driver.find_element_by_xpath('//yt-icon[@class="style-scope ytd-button-renderer"]')
    comments.append(read.text)
    
except NoSuchElementException:
    comment.append("No more")

# %%
#scrape comments
com = driver.find_elements_by_id("content-text")
for i in com:
    if i.text is None:
        comments.append("--")
    else:
        comments.append(i.text)



comments=comments[1:303]

# %%
# scrape time when comment was posted
time = driver.find_elements_by_xpath("//a[contains(text(),'ago')]")
for i in time:
    Time.append(i.text)

for i in range(0,len(Time),2):
    comment_time.append(Time[i])
    
    
comment_time=comment_time[0:302]

# %%
# scrape the comment likes
like = driver.find_elements_by_xpath("//span[@class='style-scope ytd-comment-action-buttons-renderer']")
for i in like:
    Likes.append(i.text)
    
for i in range(1,len(Likes),2):
    No_of_Likes.append(Likes[i])
    
    
    
No_of_Likes=No_of_Likes[0:302]

# %%
#creating dataframe
df=pd.DataFrame({'Comments':comments,
                'Time':comment_time,
                'Likes':No_of_Likes})
df
# Out:
#                                               Comments                Time  \
# 0    Bihar and Uttar Pradesh hindus are truly patri...  1 day ago (edited)
# 1    After the results of the 2021 elections, we, t...        23 hours ago
# 2    हिंदुस्तान के अंदर हिनदु एकजुट हो जाओ मोदी जी ...          3 days ago
# 3    Biharis are truly patriotic ..they keep our na...           1 day ago
# 4    Kashmir pandit nahin Kashmir hindu kahiye...us...          3 days ago
# ..                                                 ...                 ...
# 297                           OOO good haryana wale be         4 hours ago
# 298                           Bahichara Gaya tal lanay        23 hours ago
# 299             Hindu ya toh jaag jao ya phir bhag jao           1 day ago
# 300                             Watch....shikara,.....           1 day ago
# 301                                    Tension nana ko        22 hours ago
#
#     Likes
# 0     167
# 1      38
# 2     146
# 3      64
# 4      45
# ..    ...
# 297     1
# 298
# 299
# 300
# 301
#
# [302 rows x 3 columns]

# %% [markdown]
# # ANS10

# %%
driver=webdriver.Chrome(r'C:/Users/vinay/OneDrive/Desktop/chromedriver.exe')


url = "https://www.hostelworld.com/"
driver.get(url)

# %%
#locating the location search bar
search_loc = driver.find_element_by_id('search-input-field')
# write Lonodn in search bar
search_loc.send_keys("London")

# %%
#select london
london = driver.find_element_by_xpath('//div[@class="label"]')
london.click()

# %%
#search button
search_btn = driver.find_element_by_id('search-button')
search_btn.click()

# %%
# Make empty lists
Hostel_Name = []
Distance = []
overall_review = []
total_reviews = []
facilities = []
price = []
Rating = []
property_description = []

# %%
while(True):
    
    # Hostel name
    names = driver.find_elements_by_xpath('//h2[@class="title title-6"]')
    for name in names:
        Hostel_Name.append(name.text)
        
    # Distance from city centre
    dis = driver.find_elements_by_xpath('//span[@class="description"]')
    for d in dis:
        Distance.append(d.text)
        
    # Overall Review    
    review = driver.find_elements_by_xpath('//div[@class="keyword"]//span')
    for r in review:
        overall_review.append(r.text)
    
    # Total No of reviews     
    t_review = driver.find_elements_by_xpath('//div[@class="reviews"]')
    for tr in t_review:
        total_reviews.append(tr.text)
    
    # facilities
    service = driver.find_elements_by_xpath('//div[@class="facilities-label facilities"]')
    for s in service:
        facilities.append(s.text)
    
    # Prices    
    prices = driver.find_elements_by_xpath('//div[@class="price-col"]')
    for p in prices:
        price.append(p.text)
        
    try:
        next_button = driver.find_element_by_xpath('//div[@class="pagination-item pagination-next"]')
        next_button.click()
    except:
        break
        
        
# Separate  Privates_From price  and  Dorms_From price
Privates_From = []
for i in range(0,len(price),2):
    Privates_From.append(price[i])

Dorms_From = []
for i in range(1,len(price),2):
    Dorms_From.append(price[i])

# %%
# scrape Hostels URL
hostel_url = []

while(True):
    urls = driver.find_elements_by_xpath('//h2[@class="title title-6"]//a')
    for url in urls:
        hostel_url.append(url.get_attribute("href"))
        
    try:
        next_button = driver.find_element_by_xpath('//div[@class="pagination-item pagination-next"]')
        next_button.click()
    except:
        break
Rate = []
for page in hostel_url:
    driver.get(page)
    
    # Rating
    try:
        ratings = driver.find_element_by_xpath('/html/body/div[1]/div/div/div[1]/section/div[6]/div/div[1]/div[1]/div[1]')
        Rate.append(ratings.text)
    except NoSuchElementException:
        Rate.append("No Rating")  
    
    
    # Property Description
    try:
        pd = driver.find_element_by_xpath('/html/body/div[1]/div/div/div[1]/section/div[6]/div/div[2]/div[2]/div/div[2]')
        property_description.append(pd.text)
    except NoSuchElementException:
        property_description.append("No Description")  
# remove extra data from Rating     
all_text = []
for i in Rate:
    all_text.append(i.split())

for i in all_text:
    Rating.append(i[0])

# %%
import pandas as pd 
df =pd.DataFrame({'Hostel Name':Hostel_Name,
                'Distance from city centre':Distance,
                'Overall Review':overall_review,
                'Total Reviews':total_reviews,
                'Facilities':facilities,
                'Privates From Price':Privates_From,
                'Dorms From Price':Dorms_From,
                'Rating':Rating,
                'Property Description':property_description})
df
